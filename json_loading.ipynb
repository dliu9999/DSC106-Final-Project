# %%
import pandas as pd
import json

# %%
business_data = []
with open('yelp_academic_dataset_business.json', encoding='utf-8') as f:
    for line in f:
        business_data.append(json.loads(line))
business_df = pd.DataFrame.from_dict(business_data)
business_df.head()
# Out:
#                      address  \
# 0            10913 Bailey Rd
# 1  8880 E Via Linda, Ste 107
# 2      3554 Rue Notre-Dame O
# 3             1015 Sharp Cir
# 4         4827 E Downing Cir
#
#                                           attributes             business_id  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...  f9NumwFMBDn751xgFiRbNA
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...  Yzvjg0SayhoZgCljUJRF9Q
# 2                                               None  XNoUzKckATkOD1hP6vghZg
# 3  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...  6OAZjbxqM5ol29BuHsil3w
# 4  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...  51M2Kk903DFYI6gnB5I6SQ
#
#                                           categories             city  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...        Cornelius
# 1  Health & Medical, Fitness & Instruction, Yoga,...       Scottsdale
# 2                   Pets, Pet Services, Pet Groomers         Montreal
# ...

# %%
review_data = []
with open('yelp_academic_dataset_review.json', encoding='utf-8') as f:
    for line in f:
        j = json.loads(line)
        if j['business_id'] in wanted_ids:
            review_data.append(j)
        del j
review_df = pd.DataFrame.from_dict(review_data)
review_df.head()
# Out:
#               business_id  cool                 date  funny  \
# 0  kmF4ghAzgUNlKj0qifeSRw     0  2013-05-07 15:58:09      0
# 1  Uyla4dquQS1oD6puUCjPkA     0  2013-09-04 04:56:36      2
# 2  Uyla4dquQS1oD6puUCjPkA     0  2015-11-06 10:18:07      0
# 3  Uyla4dquQS1oD6puUCjPkA     0  2008-08-20 06:04:09      1
# 4  Uyla4dquQS1oD6puUCjPkA     1  2011-09-27 16:07:38      0
#
#                 review_id  stars  \
# 0  m7pz7SBiXmjZTKDy28LfPg    2.0
# 1  H8X9XuLO51wykE4PIa5qBQ    2.0
# 2  LZAUNFhMvodi1m67fOOMnQ    5.0
# 3  vEL7WSsiyG6i2amHW68Xgw    5.0
# 4  pU8j5e69Dgrl9aiiveJYNg    4.0
#
#                                                 text  useful  \
# 0  really? TWO AND HALF inches room from the top ...       0
# 1  Being raised in the western world, a cup of ja...       1
# 2  A very surprising new discover after Starbucks...       0
# 3  Powdered Timbits with raspberry filling.  'NUF...       0
# 4  Tim Hortons! What is it? That was the first qu...       1
#
# ...

# %%
line
# Out:
# '{"review_id":"nK0JGgr8aO4mcFPU4pDOEA","user_id":"fiA6ztHPONUkmX6yKIXyHg","business_id":"2SbyRgHWuWNlq18eHAx95Q","stars":5.0,"useful":2,"funny":0,"cool":2,"text":"Oh yeah! Not only that the service was good, the food is good the serving is good and the service is amazing. The best part is the price is really good.\\nA perfect location with lots of parking and the place looks really clean. They have an awesome lunch special that is too plenty making it very filling for the price that you\'re paying for. That is why this is one of the Japanese restaurants that I recommend for lunch specials with friends ,colleagues,Or if you are just lazy to cook. I love this place I will keep coming back here.","date":"2019-12-07 00:29:55"}\n'

# %%
toronto = business_df[business_df.city == 'Toronto']

# %%
starbucks = toronto[toronto.name == 'Starbucks']
horton = toronto[toronto.name.str.contains('Horton')]

# %%
wanted_ids = starbucks.business_id.tolist() + horton.business_id.tolist()

# %%
# review_data = []
# with open('yelp_academic_dataset_review.json', encoding='utf-8') as f:
#     for line in f:
#         review_data.append(json.loads(line))
# review_df = pd.DataFrame.from_dict(review_data)
# review_df.head()

# %%
starbucks_reviews = starbucks.merge(review_df, on='business_id', how='left')
horton_reviews = horton.merge(review_df, on='business_id', how='left')

# %%
horton_reviews
# Out:
#                         address  \
# 0          90 Adelaide Street W
# 1          90 Adelaide Street W
# 2          90 Adelaide Street W
# 3          90 Adelaide Street W
# 4          90 Adelaide Street W
# 5          90 Adelaide Street W
# 6          90 Adelaide Street W
# 7          90 Adelaide Street W
# 8     150 John Street, Unit 102
# 9     150 John Street, Unit 102
# 10    150 John Street, Unit 102
# 11    150 John Street, Unit 102
# 12    150 John Street, Unit 102
# 13    150 John Street, Unit 102
# 14          2862 Ellesmere Road
# 15          2862 Ellesmere Road
# 16          2862 Ellesmere Road
# 17          2862 Ellesmere Road
# 18          2862 Ellesmere Road
# 19          119  Spadina Avenue
# 20          119  Spadina Avenue
# 21          119  Spadina Avenue
# 22          119  Spadina Avenue
# 23          119  Spadina Avenue
# 24          119  Spadina Avenue
# 25           101 College Street
# 26           101 College Street
# 27           101 College Street
# ...

# %% [markdown]
# ## User

# %%
reviews = pd.read_csv('data/reviews.csv')
reviews.head()
# Out:
#               business_id  cool                 date  funny  \
# 0  kmF4ghAzgUNlKj0qifeSRw     0  2013-05-07 15:58:09      0
# 1  Uyla4dquQS1oD6puUCjPkA     0  2013-09-04 04:56:36      2
# 2  Uyla4dquQS1oD6puUCjPkA     0  2015-11-06 10:18:07      0
# 3  Uyla4dquQS1oD6puUCjPkA     0  2008-08-20 06:04:09      1
# 4  Uyla4dquQS1oD6puUCjPkA     1  2011-09-27 16:07:38      0
#
#                 review_id  stars  \
# 0  m7pz7SBiXmjZTKDy28LfPg    2.0
# 1  H8X9XuLO51wykE4PIa5qBQ    2.0
# 2  LZAUNFhMvodi1m67fOOMnQ    5.0
# 3  vEL7WSsiyG6i2amHW68Xgw    5.0
# 4  pU8j5e69Dgrl9aiiveJYNg    4.0
#
#                                                 text  useful  \
# 0  really? TWO AND HALF inches room from the top ...       0
# 1  Being raised in the western world, a cup of ja...       1
# 2  A very surprising new discover after Starbucks...       0
# 3  Powdered Timbits with raspberry filling.  'NUF...       0
# 4  Tim Hortons! What is it? That was the first qu...       1
#
# ...

# %%
wanted_user = reviews.user_id.unique().tolist()

# %%
user_data = []
with open('data/yelp_academic_dataset_user.json', encoding='utf-8') as f:
    for line in f:
        j = json.loads(line)
        if j['user_id'] in wanted_user:
            user_data.append(j)
        del j
user_df = pd.DataFrame.from_dict(user_data)
user_df.head()
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           3.77             1566              219              1566
# 1           3.78               95                2                95
# 2           2.95               14                0                14
# 3           3.67               28                1                28
# 4           3.89              109                5               109
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0            1180               90              129             1118
# 1              33                3                9               43
# 2               9                0                2               11
# 3              27                0               14               20
# 4             109                7               21               82
#
#    compliment_photos  compliment_plain  ...  cool  \
# 0                326              4508  ...  4031
# ...

# %%
user_df.to_csv('data/users.csv', index=False)
