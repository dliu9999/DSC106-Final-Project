# %%
import pandas as pd

# %% [markdown]
# ## Read in data

# %%
starbucks = pd.read_csv('data/starbucks.csv')
horton = pd.read_csv('data/horton.csv')
reviews = pd.read_csv('data/reviews.csv')

# %%
starbucks_reviews = starbucks.merge(reviews, on='business_id', how='left')
horton_reviews = horton.merge(reviews, on='business_id', how='left')

# %%
starbucks_reviews.head()
# Out:
#                      address  \
# 0  17-66 Wellington Street W
# 1  17-66 Wellington Street W
# 2  17-66 Wellington Street W
# 3  17-66 Wellington Street W
# 4  17-66 Wellington Street W
#
#                                           attributes             business_id  \
# 0  {'RestaurantsPriceRange2': '2', 'WiFi': "'free...  CSaB0_tKunqfcOqbw5FdAw
# 1  {'RestaurantsPriceRange2': '2', 'WiFi': "'free...  CSaB0_tKunqfcOqbw5FdAw
# 2  {'RestaurantsPriceRange2': '2', 'WiFi': "'free...  CSaB0_tKunqfcOqbw5FdAw
# 3  {'RestaurantsPriceRange2': '2', 'WiFi': "'free...  CSaB0_tKunqfcOqbw5FdAw
# 4  {'RestaurantsPriceRange2': '2', 'WiFi': "'free...  CSaB0_tKunqfcOqbw5FdAw
#
#            categories     city  \
# 0  Food, Coffee & Tea  Toronto
# 1  Food, Coffee & Tea  Toronto
# 2  Food, Coffee & Tea  Toronto
# 3  Food, Coffee & Tea  Toronto
# 4  Food, Coffee & Tea  Toronto
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '5:30-19:0', 'Tuesday': '5:30-19:0'...        1  43.647923
# 1  {'Monday': '5:30-19:0', 'Tuesday': '5:30-19:0'...        1  43.647923
# 2  {'Monday': '5:30-19:0', 'Tuesday': '5:30-19:0'...        1  43.647923
# 3  {'Monday': '5:30-19:0', 'Tuesday': '5:30-19:0'...        1  43.647923
# 4  {'Monday': '5:30-19:0', 'Tuesday': '5:30-19:0'...        1  43.647923
#
#    longitude       name  ... stars_x  state  cool                 date  funny  \
# 0 -79.381353  Starbucks  ...     4.0     ON     4  2015-01-29 18:19:52      1
# 1 -79.381353  Starbucks  ...     4.0     ON     0  2016-02-13 20:40:20      0
# 2 -79.381353  Starbucks  ...     4.0     ON     0  2017-01-31 20:17:17      0
# 3 -79.381353  Starbucks  ...     4.0     ON     0  2014-11-24 22:32:56      0
# 4 -79.381353  Starbucks  ...     4.0     ON     0  2012-01-24 19:24:54      0
#
#                 review_id  stars_y  \
# 0  3h30q6HXh9GOgPM7h4akIQ      4.0
# 1  8zdGMZtLEUikbvQ74PvZSA      4.0
# 2  Gp6SlGZJ6CB5g0haY-3Dfw      4.0
# 3  FfnpmcECGl59CK--7UuwdA      4.0
# 4  QIUEQgh0nJ0TVHWmV0h4hQ      3.0
#
#                                                 text  useful  \
# 0  This location used to be Timothy's.  I walk pa...       3
# 1  Always seems to be short lines and there are l...       0
# 2  This small and cozy Starbucks is right under T...       0
# 3  Convenient location in the concourse. There is...       0
# 4  Located in the concourse level of 66 Wellingto...       0
#
#                   user_id
# 0  2oMkzQcRL7-d7URt3Xo_Xg
# 1  vm0r8ot9ym-EGOOpMt7RBA
# 2  BVp7lc3ljjQUqipC6t1H0A
# 3  yrhB_rQyrmSQ8WFSHxzaEQ
# 4  dtanlcid8_m1L49ZK1YPfw
#
# [5 rows x 22 columns]

# %%
horton_reviews.head()
# Out:
#                 address                                         attributes  \
# 0  90 Adelaide Street W  {'OutdoorSeating': 'False', 'RestaurantsDelive...
# 1  90 Adelaide Street W  {'OutdoorSeating': 'False', 'RestaurantsDelive...
# 2  90 Adelaide Street W  {'OutdoorSeating': 'False', 'RestaurantsDelive...
# 3  90 Adelaide Street W  {'OutdoorSeating': 'False', 'RestaurantsDelive...
# 4  90 Adelaide Street W  {'OutdoorSeating': 'False', 'RestaurantsDelive...
#
#               business_id                                         categories  \
# 0  8k62wYhDVq1-652YbJi5eg  Bagels, Donuts, Food, Cafes, Coffee & Tea, Res...
# 1  8k62wYhDVq1-652YbJi5eg  Bagels, Donuts, Food, Cafes, Coffee & Tea, Res...
# 2  8k62wYhDVq1-652YbJi5eg  Bagels, Donuts, Food, Cafes, Coffee & Tea, Res...
# 3  8k62wYhDVq1-652YbJi5eg  Bagels, Donuts, Food, Cafes, Coffee & Tea, Res...
# 4  8k62wYhDVq1-652YbJi5eg  Bagels, Donuts, Food, Cafes, Coffee & Tea, Res...
#
#       city hours  is_open   latitude  longitude         name  ... stars_x  \
# 0  Toronto   NaN        1  43.649859  -79.38206  Tim Hortons  ...     3.0
# 1  Toronto   NaN        1  43.649859  -79.38206  Tim Hortons  ...     3.0
# 2  Toronto   NaN        1  43.649859  -79.38206  Tim Hortons  ...     3.0
# 3  Toronto   NaN        1  43.649859  -79.38206  Tim Hortons  ...     3.0
# 4  Toronto   NaN        1  43.649859  -79.38206  Tim Hortons  ...     3.0
#
#    state  cool                 date  funny               review_id  stars_y  \
# 0     ON     2  2017-05-27 21:35:31      1  B0Oq2lcljqWzHDluYQNawQ      4.0
# 1     ON     0  2014-06-17 15:21:11      0  CZOh_roF8lwYg_nxUAPCfA      5.0
# 2     ON     1  2012-07-03 13:46:27      2  T1BY6qw5WgLEZ_aOZG8ZQQ      2.0
# 3     ON     0  2013-05-05 21:29:55      0  o8-TYeM1W8nHj8RAp9iMhA      4.0
# 4     ON     1  2015-07-25 23:40:57      2  eGDYN3U7KZ_Fd8Q_3TfEdQ      3.0
#
#                                                 text  useful  \
# 0  Nice roomy location. Even though it was extrem...       2
# 1  The staff are always very friendly in this Tim...       0
# 2  If this Tim Horton's were to select a Huey Lew...       1
# 3  Good selection of baked goods, and the coffee ...       0
# 4  "Open 24-hours" - the neon light glows as I'm ...       1
#
#                   user_id
# 0  GZODRhmi-uUWKmWntTXujw
# 1  Oxe8DXjBOi6C-cR2w64zOg
# 2  wzyGNvArcpUjZauRWFrKHA
# 3  AUNO4CmrWzCVAtDBcEKi4g
# 4  fZ7fLMqArGTemvXPH9H3FA
#
# [5 rows x 22 columns]
